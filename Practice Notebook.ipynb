# %% [markdown]
# # Practice Notebook: Numpy. After completeion submit it via moodle  (100 points)

# %% [markdown]
# ## 1. Import numpy, Image, PrettyTable, random libraries

# %%
import numpy as np 
from PIL import Image
from numpy import random 
from prettytable import PrettyTable

# %% [markdown]
# ## 2. Open any two images from the image list using Image library and save it to image1, and image2

# %%
im1=Image.open('Pic1.jfif')
im1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=444x355 at 0x2BB0FD78F70>

# %%
im2=Image.open('Pic2.jfif')
im2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=442x355 at 0x2BB0FE403A0>

# %% [markdown]
# ## 3. Color image is a 3d Numpy array. Find out the shape of each of those images and save it array1, and array2

# %%
array1=np.array(im1)
array1.shape
# Out:
# (355, 444, 3)

# %%
array2=np.array(im2)
array2.shape
# Out:
# (355, 442, 3)

# %% [markdown]
# ## 4. If two of the image is different size, resize them. You can either resize both of them in a particular size like 400x400 or resize either of them
#
# ### use resize library from PIL
# Sample: resizedimage=image1.resize((400,400), resample=Image.NEAREST)

# %%
resized_array1=im1.resize((400,400))
resized_array1
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x2BB0FD4E580>

# %%
resized_array2=im2.resize((400,400))
resized_array2
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x2BB0FF139A0>

# %% [markdown]
# ## Find out the shape of each of those `resizedimage` and save it array1, and array2

# %%
array1=np.array(resized_array1)
array1.shape
# Out:
# (400, 400, 3)

# %%
array2=np.array(resized_array2)
array2.shape
# Out:
# (400, 400, 3)

# %% [markdown]
# ## 5.  Write down a function called "inspect" to inspect array1 and array2 Shape, length, Dimensions, and Datatype using Preetytable. Your pretty table should contain a title and look like similar to the following:
# ![image-2.png](attachment:image-2.png)

# %%
def inspect_your_array(array):
    PT=PrettyTable()
    PT.title= "Numpy array Inspection"
    PT.field_names=["Shape", "len", "Dimension", "Datatype"]
    PT.add_row([array.shape, len(array), array.ndim, array.dtype])
    print(PT)

# %%
inspect_your_array(array1)
# Out:
# +--------------------------------------------+
# |           Numpy array Inspection           |
# +---------------+-----+-----------+----------+
# |     Shape     | len | Dimension | Datatype |
# +---------------+-----+-----------+----------+
# | (400, 400, 3) | 400 |     3     |  uint8   |
# +---------------+-----+-----------+----------+

# %%
inspect_your_array(array2)
# Out:
# +--------------------------------------------+
# |           Numpy array Inspection           |
# +---------------+-----+-----------+----------+
# |     Shape     | len | Dimension | Datatype |
# +---------------+-----+-----------+----------+
# | (400, 400, 3) | 400 |     3     |  uint8   |
# +---------------+-----+-----------+----------+

# %% [markdown]
# ## 6. Perform Element wise and Array Wise comparison of array1 and array2 and add necessary comments

# %%
array1==array2
# Out:
# array([[[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        ...,
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]]])

# %%
np.array_equal(array1, array2)
# Out:
# False

# %% [markdown]
# ## 7. Create a 3D random array of saze of your array1 and array2, give it name array3

# %%
array1.size
array2.size
# Out:
# 480000

# %%
array3=random.randint(100, size=480000)
array3
# Out:
# array([71, 83, 17, ..., 55, 99, 43])

# %% [markdown]
# ## 8.Create a function called "calculation" to display `sum, min, max, mean, standard deviation, median calculations about a NumPy array using PrettyTable. Test it for array1,2,3
# ![image.png](attachment:image.png)

# %%
def calculation(array):
    PT=PrettyTable()
    PT.title= "Numpy array Calculations"
    PT.field_names=["Sum", "Min", "Max", "Mead", "STD", 'Median']
    PT.add_row([array.sum(), array.min(), array.max(), array.mean(), array.std(), np.median(array)])
    print(PT)

# %%
calculation(array1)
# Out:
# +-----------------------------------------------------------------------+
# |                        Numpy array Calculations                       |
# +----------+-----+-----+-------------------+-------------------+--------+
# |   Sum    | Min | Max |        Mead       |        STD        | Median |
# +----------+-----+-----+-------------------+-------------------+--------+
# | 36258737 |  0  | 255 | 75.53903541666666 | 70.73324675899995 |  60.0  |
# +----------+-----+-----+-------------------+-------------------+--------+

# %%
calculation(array2)
# Out:
# +-----------------------------------------------------------------------+
# |                        Numpy array Calculations                       |
# +----------+-----+-----+-------------------+-------------------+--------+
# |   Sum    | Min | Max |        Mead       |        STD        | Median |
# +----------+-----+-----+-------------------+-------------------+--------+
# | 40209209 |  0  | 255 | 83.76918541666667 | 69.96569309343535 |  61.0  |
# +----------+-----+-----+-------------------+-------------------+--------+

# %%
calculation(array3)
# Out:
# +-------------------------------------------------------------------------+
# |                         Numpy array Calculations                        |
# +----------+-----+-----+--------------------+--------------------+--------+
# |   Sum    | Min | Max |        Mead        |        STD         | Median |
# +----------+-----+-----+--------------------+--------------------+--------+
# | 23771170 |  0  |  99 | 49.523270833333335 | 28.881859360764548 |  50.0  |
# +----------+-----+-----+--------------------+--------------------+--------+

# %%
array3.resize(400,400,3)

# %% [markdown]
# ## 9.Create a function called "arithmatic" to display `Subtraction (np.subtract(a,b)), Addition,  Multiplication calculations about two NumPy array using PrettyTable. Test it for
# * array1, array3
# * array2, array3
# * array1, array2
# ![image.png](attachment:image.png)

# %%
def arithmatic(array1,array2):
    PT=PrettyTable()
    PT.title= "Numpy Array Arithmatic Operations"
    PT.field_names=['Subtraction', 'Addition', 'Multiplication']
    PT.add_row([(array1-array2), (array1+array2), (array1*array2)])
    print(PT)

# %%
arithmatic(array1,array3)
# Out:
# +--------------------------------------------------------------+
# |              Numpy Array Arithmatic Operations               |
# +-------------------+-------------------+----------------------+
# |    Subtraction    |      Addition     |    Multiplication    |
# +-------------------+-------------------+----------------------+
# |  [[[-20 -10  79]  |  [[[122 156 113]  |  [[[3621 6059 1632]  |
# |    [ 44  62  57]  |    [ 64  90 141]  |    [ 540 1064 4158]  |
# |    [ 11  19  35]  |    [ 59  95 125]  |    [ 840 2166 3600]  |
# |         ...       |         ...       |          ...         |
# |    [-36 -95 -82]  |    [ 42  99  82]  |    [ 117  194    0]  |
# |    [ -5 -25 -18]  |    [ 11  29  18]  |    [  24   54    0]  |
# |    [-26 -58 -14]] |    [ 32  62  14]] |   [  87  120    0]]  |
# |                   |                   |                      |
# |   [[-14  12  88]  |   [[102 126  94]  |   [[2552 3933  273]  |
# |    [ 14  68  68]  |    [ 82  76 120]  |    [1632  288 2444]  |
# |    [-58   5  64]  |    [124 111  96]  |    [3003 3074 1280]  |
# |         ...       |         ...       |          ...         |
# |    [-43 -55 -52]  |    [ 45  57  54]  |    [  44   56   53]  |
# |    [-40 -66 -77]  |    [ 42  68  79]  |    [  41   67   78]  |
# |    [-21 -69 -28]] |    [ 23  71  30]] |   [  22   70   29]]  |
# |                   |                   |                      |
# |   [[-30  20  82]  |   [[110 110  92]  |   [[2800 2925  435]  |
# |    [ 19 -10  17]  |    [ 57 136 153]  |    [ 722 4599 5780]  |
# |    [-59 -17  19]  |    [131 139 147]  |    [3420 4758 5312]  |
# |         ...       |         ...       |          ...         |
# |    [-89 -12 -55]  |    [ 89  12  55]  |    [   0    0    0]  |
# |    [-86 -63 -70]  |    [ 86  63  70]  |    [   0    0    0]  |
# |    [-53 -69  -6]] |    [ 53  69   6]] |   [   0    0    0]]  |
# |                   |                   |                      |
# |         ...       |         ...       |          ...         |
# |                   |                   |                      |
# |   [[-97  -3 -66]  |   [[ 97   3  66]  |   [[   0    0    0]  |
# |    [ -3 -39  -2]  |    [  3  39   2]  |    [   0    0    0]  |
# |    [-96 -65 -73]  |    [ 96  65  73]  |    [   0    0    0]  |
# |         ...       |         ...       |          ...         |
# |    [-16 -85 -26]  |    [ 16  85  26]  |    [   0    0    0]  |
# |    [-54 -65 -78]  |    [ 56  67  80]  |    [  55   66   79]  |
# |    [  0 -63  -7]] |    [ 38 101  45]] |   [ 361 1558  494]]  |
# |                   |                   |                      |
# |   [[-20  -6 -75]  |   [[ 20   6  75]  |   [[   0    0    0]  |
# |    [-74 -66 -28]  |    [ 74  66  28]  |    [   0    0    0]  |
# |    [-35  -7 -89]  |    [ 35   7  89]  |    [   0    0    0]  |
# |         ...       |         ...       |          ...         |
# |    [-70 -85 -26]  |    [ 70  85  26]  |    [   0    0    0]  |
# |    [-44 -21   4]  |    [ 54  31   6]  |    [ 245  130    5]  |
# |    [-49  41 -28]] |    [147  57 126]] |   [4802  392 3773]]  |
# |                   |                   |                      |
# |   [[-65 -40 -55]  |   [[ 65  40  55]  |   [[   0    0    0]  |
# |    [-36 -29 -63]  |    [ 36  29  63]  |    [   0    0    0]  |
# |    [-57 -53 -67]  |    [ 57  53  67]  |    [   0    0    0]  |
# |         ...       |         ...       |          ...         |
# |    [-47 -59 -19]  |    [ 47  59  19]  |    [   0    0    0]  |
# |    [-53  -8 -21]  |    [ 61  16  29]  |    [ 228   48  100]  |
# |   [  2 -42  14]]] |   [112 156 100]]] |   [3135 5643 2451]]] |
# +-------------------+-------------------+----------------------+

# %%
arithmatic(array2,array3)
# Out:
# +-----------------------------------------------------------------+
# |                Numpy Array Arithmatic Operations                |
# +-------------------+-------------------+-------------------------+
# |    Subtraction    |      Addition     |      Multiplication     |
# +-------------------+-------------------+-------------------------+
# |  [[[-71 -70  21]  |  [[[ 71  96  55]  |  [[[    0  1079   646]  |
# |    [-10   0  -3]  |    [ 10  28  81]  |    [    0   196  1638]  |
# |    [-24 -23  -5]  |    [ 24  53  85]  |    [    0   570  1800]  |
# |         ...       |         ...       |            ...          |
# |    [-23 -63 -28]  |    [ 55 131 136]  |    [  624  3298  4428]  |
# |    [ 10   9  39]  |    [ 26  63  75]  |    [  144   972  1026]  |
# |    [-11 -24  46]] |    [ 47  96  74]] |    [  522  2160   840]] |
# |                   |                   |                         |
# |   [[-58 -42  37]  |   [[ 58  72  43]  |   [[    0   855   120]  |
# |    [-34  11  14]  |    [ 34  19  66]  |    [    0    60  1040]  |
# |    [-91 -37  25]  |    [ 91  69  57]  |    [    0   848   656]  |
# |         ...       |         ...       |            ...          |
# |    [-28 -22   3]  |    [ 60  90 109]  |    [  704  1904  2968]  |
# |    [-23 -31 -20]  |    [ 59 103 136]  |    [  738  2412  4524]  |
# |    [ -4 -34  31]] |    [ 40 106  89]] |    [  396  2520  1740]] |
# |                   |                   |                         |
# |   [[-69 -29  36]  |   [[ 71  61  46]  |   [[   70   720   205]  |
# |    [-18 -57 -27]  |    [ 20  89 109]  |    [   19  1168  2788]  |
# |    [-94 -61 -22]  |    [ 96  95 106]  |    [   95  1326  2688]  |
# |         ...       |         ...       |            ...          |
# |    [-73  22   0]  |    [105  46 110]  |    [ 1424   408  3025]  |
# |    [-68 -27 -12]  |    [104  99 128]  |    [ 1548  2268  4060]  |
# |    [-35 -33  54]] |    [ 71 105  66]] |    [  954  2484   360]] |
# |                   |                   |                         |
# |         ...       |         ...       |            ...          |
# |                   |                   |                         |
# |   [[-52  94  79]  |   [[142 100 211]  |   [[ 4365   291  9570]  |
# |    [ 45  61 145]  |    [ 51 139 149]  |    [  144  3900   294]  |
# |    [-46  37  76]  |    [146 167 222]  |    [ 4800  6630 10877]  |
# |         ...       |         ...       |            ...          |
# |    [107  90 187]  |    [139 260 239]  |    [ 1968 14875  5538]  |
# |    [ 75 117 143]  |    [185 249 301]  |    [ 7150 12078 17538]  |
# |    [108 100 195]] |    [146 264 247]] |    [ 2413 14924  5746]] |
# |                   |                   |                         |
# |   [[ 25  91  69]  |   [[ 65 103 219]  |   [[  900   582 10800]  |
# |    [-28  32 117]  |    [120 164 173]  |    [ 3404  6468  4060]  |
# |    [ 12  92  57]  |    [ 82 106 235]  |    [ 1645   693 12994]  |
# |         ...       |         ...       |            ...          |
# |    [ 57  94 189]  |    [197 264 241]  |    [ 8890 15215  5590]  |
# |    [ 79 154 218]  |    [177 206 220]  |    [ 6272  4680   219]  |
# |    [ 25 169 138]] |    [221 185 292]] |    [12054  1416 16555]] |
# |                   |                   |                         |
# |   [[-18  59  91]  |   [[112 139 201]  |   [[ 3055  3960  8030]  |
# |    [ 10  69  82]  |    [ 82 127 208]  |    [ 1656  2842  9135]  |
# |    [-12  44  77]  |    [102 150 211]  |    [ 2565  5141  9648]  |
# |         ...       |         ...       |            ...          |
# |    [ 82 122 198]  |    [176 240 236]  |    [ 6063 10679  4123]  |
# |    [ 70 167 192]  |    [184 191 242]  |    [ 7239  2148  5425]  |
# |   [ 66  76 170]]] |   [176 274 256]]] |   [ 6655 17325  9159]]] |
# +-------------------+-------------------+-------------------------+

# %%
arithmatic(array1,array2)
# Out:
# +-----------------------------------------------------------+
# |             Numpy Array Arithmatic Operations             |
# +-------------------+-------------------+-------------------+
# |    Subtraction    |      Addition     |   Multiplication  |
# +-------------------+-------------------+-------------------+
# |  [[[ 51  60  58]  |  [[[ 51  86 134]  |  [[[  0 181  64]  |
# |    [ 54  62  60]  |    [ 54  90 138]  |    [  0  40  21]  |
# |    [ 35  42  40]  |    [ 35  72 120]  |    [  0  87 128]  |
# |         ...       |         ...       |         ...       |
# |    [243 224 202]  |    [ 19  36  54]  |    [ 48  68   0]  |
# |    [241 222 199]  |    [ 21  38  57]  |    [ 54  72   0]  |
# |    [241 222 196]] |    [ 21  38  60]] |    [ 54  72   0]] |
# |                   |                   |                   |
# |   [[ 44  54  51]  |   [[ 44  84 131]  |   [[  0  11  56]  |
# |    [ 48  57  54]  |    [ 48  87 134]  |    [  0  56 176]  |
# |    [ 33  42  39]  |    [ 33  74 121]  |    [  0 160 208]  |
# |         ...       |         ...       |         ...       |
# |    [241 223 201]  |    [ 17  35  57]  |    [ 16  34  56]  |
# |    [239 221 199]  |    [ 19  37  59]  |    [ 18  36  58]  |
# |    [239 221 197]] |    [ 19  37  61]] |    [ 18  36  60]] |
# |                   |                   |                   |
# |   [[ 39  49  46]  |   [[ 41  81 128]  |   [[ 40  16 239]  |
# |    [ 37  47  44]  |    [ 39  79 126]  |    [ 38 240 157]  |
# |    [ 35  44  41]  |    [ 37  78 125]  |    [ 36  13 158]  |
# |         ...       |         ...       |         ...       |
# |    [240 222 201]  |    [ 16  34  55]  |    [  0   0   0]  |
# |    [238 220 198]  |    [ 18  36  58]  |    [  0   0   0]  |
# |    [238 220 196]] |    [ 18  36  60]] |    [  0   0   0]] |
# |                   |                   |                   |
# |         ...       |         ...       |         ...       |
# |                   |                   |                   |
# |   [[211 159 111]  |   [[ 45  97 145]  |   [[  0   0   0]  |
# |    [208 156 109]  |    [ 48 100 147]  |    [  0   0   0]  |
# |    [206 154 107]  |    [ 50 102 149]  |    [  0   0   0]  |
# |         ...       |         ...       |         ...       |
# |    [133  81  43]  |    [123 175 213]  |    [  0   0   0]  |
# |    [127  74  35]  |    [131 184 223]  |    [130 183 222]  |
# |    [148  93  54]] |    [146 201 240]] |    [109 130 103]] |
# |                   |                   |                   |
# |   [[211 159 112]  |   [[ 45  97 144]  |   [[  0   0   0]  |
# |    [210 158 111]  |    [ 46  98 145]  |    [  0   0   0]  |
# |    [209 157 110]  |    [ 47  99 146]  |    [  0   0   0]  |
# |         ...       |         ...       |         ...       |
# |    [129  77  41]  |    [127 179 215]  |    [  0   0   0]  |
# |    [133  81  42]  |    [133 185 224]  |    [128 132  71]  |
# |    [182 128  90]] |    [172 226   8]] |    [139 225  39]] |
# |                   |                   |                   |
# |   [[209 157 110]  |   [[ 47  99 146]  |   [[  0   0   0]  |
# |    [210 158 111]  |    [ 46  98 145]  |    [  0   0   0]  |
# |    [211 159 112]  |    [ 45  97 144]  |    [  0   0   0]  |
# |         ...       |         ...       |         ...       |
# |    [127  75  39]  |    [129 181 217]  |    [  0   0   0]  |
# |    [133  81  43]  |    [131 183 221]  |    [252 204 100]  |
# |   [192 138 100]]] |   [178 232  14]]] |   [241 247 109]]] |
# +-------------------+-------------------+-------------------+

# %% [markdown]
# ## 10. What is the difference between reshape and resize? Reshape and resize 3D array2 to a 2D array. Make sure keep in mind the original shape.

# %% [markdown]
# Resize changes the shape of the original array globally while reshape only changes the shape of the original locally

# %%
array2.reshape(1000,480)
array2
# Out:
# array([[[  0,  13,  38],
#         [  0,  14,  39],
#         [  0,  15,  40],
#         ...,
#         [ 16,  34,  54],
#         [ 18,  36,  57],
#         [ 18,  36,  60]],
#
#        [[  0,  15,  40],
#         [  0,  15,  40],
#         [  0,  16,  41],
#         ...,
#         [ 16,  34,  56],
#         [ 18,  36,  58],
#         [ 18,  36,  60]],
#
#        [[  1,  16,  41],
#         [  1,  16,  41],
#         [  1,  17,  42],
#         ...,
#         [ 16,  34,  55],
#         [ 18,  36,  58],
#         [ 18,  36,  60]],
#
#        ...,
#
#        [[ 45,  97, 145],
#         [ 48, 100, 147],
#         [ 50, 102, 149],
#         ...,
#         [123, 175, 213],
#         [130, 183, 222],
#         [127, 182, 221]],
#
#        [[ 45,  97, 144],
#         [ 46,  98, 145],
#         [ 47,  99, 146],
#         ...,
#         [127, 179, 215],
#         [128, 180, 219],
#         [123, 177, 215]],
#
#        [[ 47,  99, 146],
#         [ 46,  98, 145],
#         [ 45,  97, 144],
#         ...,
#         [129, 181, 217],
#         [127, 179, 217],
#         [121, 175, 213]]], dtype=uint8)

# %%
array2.shape
# Out:
# (400, 400, 3)

# %%
array2.resize(1000,480)
array2
# Out:
# array([[  0,  13,  38, ...,   2,   2,   9],
#        [  2,   2,  10, ...,   0,  20,  33],
#        [  0,  19,  33, ...,   1,  12,  32],
#        ...,
#        [198, 225, 242, ...,  43,  96, 159],
#        [ 46,  97, 160, ..., 120, 154, 182],
#        [123, 153, 181, ..., 121, 175, 213]], dtype=uint8)

# %%
array2.shape
# Out:
# (1000, 480)

# %% [markdown]
# ## 11. Vertically stack array1 and array3 and create new array4

# %%
array4=np.vstack((array1,array3))
array4
# Out:
# array([[[51, 73, 96],
#         [54, 76, 99],
#         [35, 57, 80],
#         ...,
#         [ 3,  2,  0],
#         [ 3,  2,  0],
#         [ 3,  2,  0]],
#
#        [[44, 69, 91],
#         [48, 72, 94],
#         [33, 58, 80],
#         ...,
#         [ 1,  1,  1],
#         [ 1,  1,  1],
#         [ 1,  1,  1]],
#
#        [[40, 65, 87],
#         [38, 63, 85],
#         [36, 61, 83],
#         ...,
#         [ 0,  0,  0],
#         [ 0,  0,  0],
#         [ 0,  0,  0]],
#
#        ...,
#
#        [[97,  3, 66],
#         [ 3, 39,  2],
#         [96, 65, 73],
#         ...,
#         [16, 85, 26],
#         [55, 66, 79],
#         [19, 82, 26]],
#
#        [[20,  6, 75],
#         [74, 66, 28],
#         [35,  7, 89],
#         ...,
#         [70, 85, 26],
#         [49, 26,  1],
#         [98,  8, 77]],
#
#        [[65, 40, 55],
#         [36, 29, 63],
#         [57, 53, 67],
#         ...,
#         [47, 59, 19],
#         [57, 12, 25],
#         [55, 99, 43]]])

# %% [markdown]
# ## 12. Save array4 at your system and load it back

# %%
np.save('array4.npy',array4)

# %%
np.load('array4.npy')
# Out:
# array([[[51, 73, 96],
#         [54, 76, 99],
#         [35, 57, 80],
#         ...,
#         [ 3,  2,  0],
#         [ 3,  2,  0],
#         [ 3,  2,  0]],
#
#        [[44, 69, 91],
#         [48, 72, 94],
#         [33, 58, 80],
#         ...,
#         [ 1,  1,  1],
#         [ 1,  1,  1],
#         [ 1,  1,  1]],
#
#        [[40, 65, 87],
#         [38, 63, 85],
#         [36, 61, 83],
#         ...,
#         [ 0,  0,  0],
#         [ 0,  0,  0],
#         [ 0,  0,  0]],
#
#        ...,
#
#        [[97,  3, 66],
#         [ 3, 39,  2],
#         [96, 65, 73],
#         ...,
#         [16, 85, 26],
#         [55, 66, 79],
#         [19, 82, 26]],
#
#        [[20,  6, 75],
#         [74, 66, 28],
#         [35,  7, 89],
#         ...,
#         [70, 85, 26],
#         [49, 26,  1],
#         [98,  8, 77]],
#
#        [[65, 40, 55],
#         [36, 29, 63],
#         [57, 53, 67],
#         ...,
#         [47, 59, 19],
#         [57, 12, 25],
#         [55, 99, 43]]])
